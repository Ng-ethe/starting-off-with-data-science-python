# %%
print('hello world')
# Out:
# hello world

# %%
#printing a statement
print('hello world')
# Out:
# hello world

# %%
# # STRINGS


# ## Concept-Alert:
# Strings
# Strings are used in Python to record text information, such as name. Strings in Python are actually a sequence, which basically means Python keeps track of every element in the string as a sequence. For example, Python understands the string "hello' to be a sequence of letters in a specific order. This means we will be able to use indexing to grab particular letters (like the first letter, or the last letter).

# This idea of a sequence is an important one in Python and we will touch upon it later on in the future.

# In this lecture we'll learn about the following:

# 1.) Creating Strings
# 2.) Printing Strings
# 3.) String Indexing and Slicing
# 4.) String Properties
# 5.) String Methods
# 6.) Print Formatting

# %%
#printing a statement
print('hello world')

a = 'HELLO WORLD'
print(a)

print(type(a))
print(len(a))
# Out:
# hello world
# HELLO WORLD
# <class 'str'>
# 11

# %%
f = 1.21431231243423423
print(f)

# %%
print(a[0:5])

# %%
print(round(f,2))

# %%
print(f)

# %%
print(a[5:11])
#OR
print(a[5:len(a)])

# %%
print(a[-5:])

# %%
print("%.2f"%f)

# %%
multi = """This is a multi line 
string
hello world
"""
print(multi)
#OR
print("This is \\na Multi \nString")
#note: \\n prints \n

# %%
#  >>> 125650429603636838/(2**53)
#   13.949999999999999

#   >>> 234042163/(2**24)
#   13.949999988079071

#   >>> a=13.946
#   >>> print(a)
#   13.946
#   >>> print("%.2f" % a)
#   13.95
#   >>> round(a,2)
#   13.949999999999999
#   >>> print("%.2f" % round(a,2))
#   13.95
#   >>> print("{0:.2f}".format(a))
#   13.95
#   >>> print("{0:.2f}".format(round(a,2)))
#   13.95
#   >>> print("{0:.15f}".format(round(a,2)))
#   13.94999999999999

# %%
print(a.title())
# Out:
# Hello

# %%
a.lower()
# Out:
# 'hello'

# %%
print(a)
# Out:
# hello

# %%
a = a.lower()

print(a)
# Out:
# hello

# %%
a = a.upper()
print(a)
# Out:
# HELLO

# %%
a = a.title()
print(a)
# Out:
# Hello

# %%
a_capitalize = a.capitalize()
print (a_capitalize)
print(a_capitalize.title())
# Out:
# Hello
# Hello

# %%
#str.strip() can be used to remove white spaces
a= " Hello World "
print(a)
a = a.lstrip()
print(a)
a = a.strip()
print (a)

# string to list conversion
print(list(a)[0:11])
# Out:
#  Hello World
# Hello World
# Hello World
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
# String Formatting
name = "Einstein"
age = 22
married = True

print("My name is %s, my age is %s, and it is %s that I am married" % (name, age, married))

print("My name is {}, my age is {}, and it is {} that I am married".format(name, age, married))

print("My name is {n}, my age is {a}, and it is {m} that I am married".format(n=name, a=age, m=married))

#best way to format: FSTRING for python 3.7
print(f"Myy name is: {name},my age is: {age}, and it is {married} that I am married")
# Out:
#   File "<ipython-input-76-71310696e535>", line 13
#     print(f"Myy name is: {name},my age is: {age}, and it is {married} that I am married")
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
# SPlitting a string
word = "h.e.l.l.o"
word.split('.')[0:3]

# %%
sent = "The quick brown fox jumped over the lazy dog "
sent.split(" ")

# %%
# TAKING INPUT FROM THE USER

number1 = input("Enter the first Number")

number2 = input("Enter the sencond number")

addition = int(number1) + int(number2) #type conversion

print(addition)

# %%
#Mini Challenge Its your turn now!! store the word `hello` in my_string.
#print the my_string + name.
#MINI CHALLENGE 
my_string = 'Hello'
name = input('Enter your name: \n')
print('{} {}'.format(my_string, name))
print('%s %s'%(my_string,name))

# %%
a = input('Enter the first Number: ')

b = input('Enter the second Number: ')

mean = (int(a)+int(b))/2
print('The Mean is',mean)
type(mean)

# %%
a= 'hello'
print(list(a))

# %%
my_list = ['one', 
          'two',
          99.23,
          'four']
# concatinating a list
#1
my_list = my_list + [100.23]
my_list
#2 (using extend)
my_list.extend('six')
print(my_list)
# Out:
# ['one', 'two', 99.23, 'four', 100.23, 's', 'i', 'x']

# %%
my_list2 = [99, 44]
my_list.append(my_list2)
print(my_list)

# %%
my_list4 = [44, 55, 61, 2, 44, 9]
my_list4.sort()
print(my_list4)

# %%
my_list
# Out:
# ['one', 'two', 99.23, 'four', 100.23, 's', 'i', 'x']

# %%
my_dict = {'apple':'red','mango':'yellow'}
my_dict['apple']
my_dict.pop
# Out:
# 'red'

# %%
a = 2
isinstance(a,int)
# Out:
# True

# %%
print(my_list)
# Out:
# ['one', 'two', 99.23, 'four', 100.23, 's', 'i', 'x']

# %%
#Iterative Loops
#for loop
for i in range(len(my_list)):
    print(my_list[i])
# Out:
# one
# two
# 99.23
# four
# 100.23
# s
# i
# x

# %%
sq_rt = []
my_list = [321, 23, 2 , 55, 77]
for i in range(len(my_list)):
    sq_rt.append(my_list[i]**0.5)
print(sq_rt)
# Out:
# [17.916472867168917, 4.795831523312719, 1.4142135623730951, 7.416198487095663, 8.774964387392123]

# %%
# Alternate way to print list  values
for value in my_list:
    print(value)
# Out:
# 321
# 23
# 2
# 55
# 77

# %%
# %timeit [print()]
# Out:
# 68.8 µs ± 1.68 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
list_ = [27, 123, 43, 45324, 1233123]

[(i**(1/3)) for i in list_]
# Out:
# [3.0,
#  4.97318983326859,
#  3.503398060386724,
#  35.654094422749274,
#  107.23473084768453]

# %%
for i in list_:
    print(i**(1/3))
# Out:
# 4.97318983326859
# 4.97318983326859
# 3.503398060386724
# 35.654094422749274
# 107.23473084768453

# %%
# use pprint to print
import pprint
pprint.pprint(list_)
# Out:
# [27, 123, 43, 45324, 1233123]

# %%
my_list = range(0,100)
print (my_list)
# Out:
# range(0, 100)

# %%
my_list = range(100,999)
iterator = iter(my_list)
next(iterator)
# Out:
# 100

# %%
[value **(1/3) for value in iterator]
# Out:
# [4.657009507803835,
#  4.672328728355259,
#  4.687548147653597,
#  4.7026693754415145,
#  4.7176939803165325,
#  4.732623491163368,
#  4.7474593985234,
#  4.762203155904598,
#  4.776856181035017,
#  4.791419857062784,
#  4.805895533705332,
#  4.820284528350459,
#  4.834588127111639,
#  4.848807585839879,
#  4.862944131094279,
#  4.876998961073313,
#  4.890973246508748,
#  4.904868131524016,
#  4.9186847344587274,
#  4.93242414866094,
#  4.9460874432487,
#  4.9596756638423,
#  4.97318983326859,
#  4.986630952238645,
#  5.0,
#  5.0132979349645845,
#  5.026525695313479,
#  5.039684199579492,
#  5.05277434720856,
#  5.065797019100886,
#  5.0787530781327,
#  5.091643369659488,
#  5.104468722001463,
#  5.117229946912048,
#  5.12992784003009,
#  5.14256318131647,
#  5.155136735475772,
#  5.167649252363622,
#  5.180101467380292,
#  5.1924941018511035,
#  5.2048278633942004,
#  5.217103446276167,
#  5.229321531755983,
#  5.241482788417793,
#  5.253587872492901,
#  5.265637428171437,
# ...

# %%
next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-5-4ce711c44abc> in <module>
# ----> 1 next(iterator)
#
# StopIteration:

# %%
try:
    next(iterator)
except StopIteration:
    print('Exception Handled')
    print('Iteration Has Stopped')
finally: 
    iterator = iter(my_list)
    print('The Iterator has been reconfigured')
# Out:
# Exception Handled
# Iteration Has Stopped
# The Iterator has been reconfigured

# %%
next(iterator)
# Out:
# 100

# %%
next(iterator)
# Out:
# 101

# %%
# !ls #enlists the files
# Out:
# IntroToPython.ipynb  myfile.txt  notebook.ipynb

# %%
# !wget https://raw.githubusercontent.com/ashharr/r4ds/master/data/heights.csv
# Out:
# --2019-01-21 16:40:32--  https://raw.githubusercontent.com/ashharr/r4ds/master/data/heights.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.152.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.152.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53636 (52K) [text/plain]
# Saving to: 'heights.csv'
#
#      0K .......... .......... .......... .......... .......... 95%  715K 0s
#     50K ..                                                    100% 12.0G=0.07s
#
# 2019-01-21 16:40:32 (749 KB/s) - 'heights.csv' saved [53636/53636]

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
with open('heights.csv','r') as file:
    print(file.readlines())
# Out:
# ['"earn","height","sex","ed","age","race"\n', '50000,74.4244387818035,"male",16,45,"white"\n', '60000,65.5375428255647,"female",16,58,"white"\n', '30000,63.6291977374349,"female",16,29,"white"\n', '50000,63.1085616752971,"female",16,91,"other"\n', '51000,63.4024835710879,"female",17,39,"white"\n', '9000,64.3995075440034,"female",15,26,"white"\n', '29000,61.6563258264214,"female",12,49,"white"\n', '32000,72.6985437364783,"male",17,46,"white"\n', '2000,72.0394668497611,"male",15,21,"hispanic"\n', '27000,72.2349325611722,"male",12,26,"white"\n', '6530,69.5121464275289,"male",16,65,"white"\n', '30000,68.0316082600038,"male",11,34,"white"\n', '12000,67.556933917338,"male",12,27,"white"\n', '12000,65.4305870763492,"female",12,51,"white"\n', '22000,65.6628545243293,"female",16,35,"white"\n', '17000,67.7587687384803,"male",12,58,"white"\n', '40000,68.3518425801303,"female",14,29,"white"\n', '44000,69.6095718003344,"male",13,44,"white"\n', '7000,64.1845656777732,"female",12,55,"black"\n', '53
# ...
